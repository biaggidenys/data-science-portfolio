# %% [markdown]
# ## Usando Pandas e Numpy
# ## Considere o dataset na url https://raw.githubusercontent.com/rsram27/iris/main/diabetes.csv
# ### a) Utilize o metodo de leitura direto da URL (Metodo 4 do nosso Colab de Arquivos)
# ### b) Verifique valores ausentes
# ### c) Plotar a distribuição de variaveis para 3 colunas distinas
# ### d) Estatísticas descritivas para grupos com diabetes Dica : "Diabetic" = 1:
# ### e) Veja correlação entre váriaveis. É possivel observar alguma que faça sentido?
#
# ### No entanto veja que:
# Para interpretar os resultados da função corr(), é importante considerar o intervalo de valores possíveis para os coeficientes de correlação. Como mencionado anteriormente, os coeficientes de correlação variam de -1 a 1.
#
#     Um coeficiente de correlação de 1 indica uma forte relação positiva entre as duas variáveis. Isso significa que, quando uma variável aumenta, a outra variável também aumenta.
#     Um coeficiente de correlação de -1 indica uma forte relação negativa entre as duas variáveis. Isso significa que, quando uma variável aumenta, a outra variável diminui.
#     Um coeficiente de correlação próximo de 0 indica que não há relação entre as duas variáveis.
#
# É importante notar que a correlação não implica causalidade. Apenas porque duas variáveis estão correlacionadas não significa que uma causa a outra. Por exemplo, o fato de que as vendas de sorvetes aumentam no verão não significa que o sorvete cause o verão.
#
# ### f) Calcular a média da idade dos pacientes diabéticos:
# ### g) Criar uma nova coluna no Dataframe com o IMC ao quadrado. Em seguida exiba novamente o Dataframe e gere uma analise nova e rapida desse dataframe (describe)
# ### h) Criar uma coluna que mostre a classificação da obesidade com base na tabela de IMC abaixo
# ![image.png](data:image/png;base64,...)

# %%
# Declarar importação e fazer a leitura

# %%
# Podemos fazer leitura diretamente de uma url

# Declarando a variavel e lendo pelo metodo read_csv

url = 'https://raw.githubusercontent.com/rsram27/iris/main/diabetes.csv'

iris_url = pd.read_csv(url)
iris_url
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0       1354778            0            171                      80
# 1       1147438            8             92                      93
# 2       1640031            7            115                      47
# 3       1883350            9            103                      78
# 4       1424119            1             85                      59
# ...         ...          ...            ...                     ...
# 9995    1469198            6             95                      85
# 9996    1432736            0             55                      51
# 9997    1410962            5             99                      59
# 9998    1958653            0            145                      67
# 9999    1332938           10            100                      54
#
#       TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 0                   34            23  43.509726          1.213191   21
# ...

# %%
# Valores Ausentes

# %%
# prompt:  Verifique valores ausentes em "iris_url"

iris_url.isnull().sum()
# Out:
# PatientID                 0
# Pregnancies               0
# PlasmaGlucose             0
# DiastolicBloodPressure    0
# TricepsThickness          0
# SerumInsulin              0
# BMI                       0
# DiabetesPedigree          0
# Age                       0
# Diabetic                  0
# dtype: int64

# %%
# Distribuição para 3 colunas

# %%
# prompt: Plotar a distribuição de variaveis para 3 colunas distinas

import matplotlib.pyplot as plt

# Selecionando 3 colunas
iris_url_subset = iris_url[['Age', 'Pregnancies', 'SerumInsulin']]

# Plotando a distribuição de cada coluna
for column in iris_url_subset:
  plt.hist(iris_url_subset[column])
  plt.title(f'Distribuição da variável {column}')
  plt.show()

# %%
# prompt: create the same view as last row but with interactive chart

import plotly.express as px

for column in iris_url_subset:
  fig = px.histogram(iris_url_subset, x=column, nbins=20, title=f'Distribuição da variável {column}')
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Estatísticas descritivas para pacientes diabeticos

# %%
# prompt: filter Diabetic=1

# Filter Diabetic=1
diabetes_patients = iris_url[iris_url['Diabetic'] == 1]
diabetes_patients
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 3       1883350            9            103                      78
# 8       1201647            8             80                      95
# 12      1848869            5            114                     101
# 15      1738587            3            109                      77
# 16      1884264            3            106                      64
# ...         ...          ...            ...                     ...
# 9982    1508248            1            108                      61
# 9985    1439126            2            100                      47
# 9991    1819056            4            140                      94
# 9992    1639966            4            100                      83
# 9997    1410962            5             99                      59
#
#       TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 3                   25           304  29.582192          1.282870   43
# ...

# %%
# prompt: create a normal distribution for all metrics with the metric "Age" in the X axis

import matplotlib.pyplot as plt
for column in iris_url_subset.columns:
  if column != 'Age':
    sns.displot(x="Age", y=column, kind="kde", data=iris_url)
    plt.title(f'Distribuição normal de {column} por Idade')
    plt.show()

# %%
# É notal que em mulheres de menos idade (20 a 30 anos) são as que tem maior concentração de Insulina Serum e também são as com Pregnancy Type entre 0 e 2.5

# %%
# Correlação de váriaveis
# Tecer os comentários a respeito de sua observação, atentando-se para o fato descrito no box.

# %%
# prompt: create a heatmap for diabetes_patients

import matplotlib.pyplot as plt
import seaborn as sns

# Create a heatmap of the correlations between the columns
sns.heatmap(diabetes_patients.corr(), annot=True)
plt.show()

# %%
# Não podemos afirmar que os parâmetros têm forte correlação entre si, na verdade todos tendem a zero. Isso mostra uma correlação bem fraca entre as métricas analisadas.

# %%
# Média de idade dos pacientes diabeticos

# %%
diabetes_patients
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 3       1883350            9            103                      78
# 8       1201647            8             80                      95
# 12      1848869            5            114                     101
# 15      1738587            3            109                      77
# 16      1884264            3            106                      64
# ...         ...          ...            ...                     ...
# 9982    1508248            1            108                      61
# 9985    1439126            2            100                      47
# 9991    1819056            4            140                      94
# 9992    1639966            4            100                      83
# 9997    1410962            5             99                      59
#
#       TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 3                   25           304  29.582192          1.282870   43
# ...

# %%
# prompt: calculate average of "Age" column

average_age = diabetes_patients['Age'].mean()
print(f"Average age of diabetic patients: {average_age}")
# Out:
# Average age of diabetic patients: 36.22607655502392

# %%
# Criar uma coluna nova com IMC (BMI) ao quadrado

# %%
# prompt: Criar uma coluna nova com IMC (BMI) ao quadrado

diabetes_patients['BMI_squared'] = diabetes_patients['BMI'] ** 2
diabetes_patients
# Out:
# <ipython-input-45-e25085bb3240>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 3       1883350            9            103                      78
# 8       1201647            8             80                      95
# 12      1848869            5            114                     101
# 15      1738587            3            109                      77
# 16      1884264            3            106                      64
# ...         ...          ...            ...                     ...
# 9982    1508248            1            108                      61
# 9985    1439126            2            100                      47
# ...

# %%
# Criar uma nova coluna com a coluna classificação de magreza

# %%
# prompt: crie as colunas CLASSIFICAÇAO (Magreza, normal, sobrepeso, obesidade e obesidade grave) e a coluna OBESIDADE (0, 1, 2 ou 3). De acordo com BMI IMC menor que 185 é classificado como MAGREZA, Obesidade = 0
# IMC entre 18.5 e 24.9 é classificado como NORMAL, Obesidade = 0
# IMC entre 25 e 29.9 é classificado como SOBREPESO, Obesidade = 1
# IMC entre 30 e 39.9 é classificado como OBESIDADE, Obesidade = 2

def classify_bmi(bmi):
  if bmi < 18.5:
    return "MAGREZA", 0
  elif bmi >= 18.5 and bmi <= 24.9:
    return "NORMAL", 0
  elif bmi >= 25 and bmi <= 29.9:
    return "SOBREPESO", 1
  else:
    return "OBESIDADE", 2

diabetes_patients["CLASSIFICAÇÃO"], diabetes_patients["OBESIDADE"] = zip(*diabetes_patients["BMI"].apply(classify_bmi))
diabetes_patients
# Out:
# <ipython-input-46-7ae8464e4aca>:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-46-7ae8464e4aca>:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 3       1883350            9            103                      78
# 8       1201647            8             80                      95
# 12      1848869            5            114                     101
# ...
